# %% [markdown]
# # Cleaning of Interglad data-set

# %%
from glassdata import GlassData

# Neme of the data-set saved from Interglad V8:
filename='DataSet/ndInterglad.csv'

# Setting of parameters used in the cleaning operation
xtotal=0.98 # Threshold to consider the glass composition as complete
xminor=0.01 # Minimum of molar fraction to consider the molar fraction as equal to zero
probamin=0.02 # 
probamax=0.99
filteringoxide=False
minoxidefraction=0.
Plot=True
db=GlassData()
db.nameproperty='nd'
db.datacleaning(filename,xtotal,probamin,probamax,xminor,minoxidefraction,filteringoxide,Plot)
# Out:
# /home/fpigeonneau/ownCloud/Python/Utils/glassdata.py:423: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(filename,skiprows=27)
# Before cleaning, the number of data are  23473
# Number of oxides after removal of minor representation is  27
# Numbers of data after x>xtotal:  14396
# minval of y:  1.4783823529411764
# maxval of y:  2.252794117647059
# Numbers of data after filtering:  14137
# For  SiO2 , xmax= 1.0
# For  B2O3 , xmax= 0.9591
# For  Al2O3 , xmax= 0.8319
# For  MgO , xmax= 0.5238
# For  CaO , xmax= 0.6633
# For  BaO , xmax= 0.8239000000000001
# For  Li2O , xmax= 0.6562
# For  Na2O , xmax= 0.9008
# For  K2O , xmax= 0.6862
# For  ZnO , xmax= 0.7000000000000001
# For  SrO , xmax= 0.6409999999999999
# For  PbO , xmax= 0.848
# For  SnO , xmax= 0.8200000000000001
# For  As2O3 , xmax= 0.03
# For  Y2O3 , xmax= 1.0
# For  Sb2O3 , xmax= 0.9
# For  La2O3 , xmax= 1.0
# For  Bi2O3 , xmax= 0.75
# ...
